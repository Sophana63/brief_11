# %%
import pandas as pd
from pandasql import sqldf
import mysql.connector as mysql

# %%
df_com = pd.read_excel('Donnees_Immo/donnees_communes.xlsx')

df_com = df_com[['CODCOM', 'COM', 'PTOT', 'CODDEP']]
df_com["id"] = df_com['CODDEP'].astype(str) + df_com['CODCOM'].map("{:03}".format)
commune = df_com[['id', 'COM', 'PTOT', 'CODDEP']]
q = "SELECT * FROM commune GROUP BY id"
commune = sqldf(q, globals())
commune
# Out:
#            id                       COM   PTOT CODDEP
# 0       01001  L'Abergement-Cl̩menciat    798     01
# 1       01002     L'Abergement-de-Varey    257     01
# 2       01004        Amb̩rieu-en-Bugey  14514     01
# 3       01005      Amb̩rieux-en-Dombes   1776     01
# 4       01006                  Ambl̩on    118     01
# ...       ...                       ...    ...    ...
# 34986  974420            Sainte-Suzanne  24292    974
# 34987  974421                   Salazie   7209    974
# 34988  974422                 Le Tampon  80833    974
# 34989  974423         Les Trois-Bassins   7106    974
# 34990  974424                    Cilaos   5623    974
#
# [34991 rows x 4 columns]

# %%
db = mysql.connect(
    host = "localhost",
    user = "root",
    passwd = "",
    database = "valeur_fonciere"
)

cursor = db.cursor()

sql = "INSERT INTO commune(id, nom_com, population, id_dep) VALUES(%s,%s,%s,%s)"
for i,row in commune.iterrows():
    cursor.execute(sql, tuple(row))    
    db.commit()

db.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Input In [3], in <cell line: 11>()
#      10 sql = "INSERT INTO commune(id, nom_com, population, id_dep) VALUES(%s,%s,%s,%s)"
#      11 for i,row in commune.iterrows():
# ---> 12     cursor.execute(sql, tuple(row))
#      13     db.commit()
#      15 db.close()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\cursor.py:551, in MySQLCursor.execute(self, operation, params, multi)
#     549 else:
#     550     try:
# --> 551         self._handle_result(self._connection.cmd_query(stmt))
#     552     except errors.InterfaceError:
#     553         if self._connection._have_next_result:  # pylint: disable=W0212
#
# File C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py:490, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     488 if not isinstance(query, bytes):
#     489     query = query.encode('utf-8')
# --> 490 result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     492 if self._have_next_result:
#     493     raise errors.InterfaceError(
#     494         'Use cmd_query_iter for statements with multiple queries.')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\mysql\connector\connection.py:395, in MySQLConnection._handle_result(self, packet)
#     393     return self._handle_eof(packet)
#     394 elif packet[4] == 255:
# --> 395     raise errors.get_exception(packet)
#     397 # We have a text result set
#     398 column_count = self._protocol.parse_column_count(packet)
#
# IntegrityError: 1062 (23000): Duplicata du champ '01001' pour la clef 'PRIMARY'
